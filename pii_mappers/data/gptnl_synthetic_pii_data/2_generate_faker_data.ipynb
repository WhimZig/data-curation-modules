# %%
from faker import Faker

fake = Faker(['nl_NL'])

# %%
print(fake.ssn())
# Out:
# 903456187

# %%
fake = Faker(['en_GB', 'en_IE', 'en_IN', 'en_PH'])
fake.iban()
# Out:
# 'GB41BMZW02073838355654'

# %%
fake = Faker(['en_GB', 'en_US'])
fake.passport_number()
# Out:
# '457989664'
